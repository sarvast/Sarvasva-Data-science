# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,69,85,74,96,45,36,15])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
print(s)
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     69
# 5     85
# 6     74
# 7     96
# 8     45
# 9     36
# 10    15
# dtype: int64

# %%
s1 = pd.Series([10, 20, 30], index=["a", "b", "c"])

# %%
s1["b"]
# Out:
# np.int64(20)

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

df = pd.DataFrame(data)
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.
# Out:
#   Cell In[16], line 1
#     df.
#        ^
# SyntaxError: invalid syntax
