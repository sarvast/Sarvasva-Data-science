# %%
import json

# %%
def load_data(data.json):
    with open(data.json, 'r') as f:
        data = json.load(f)
    return data
# Out:
#   File "/tmp/ipython-input-3470160485.py", line 1
#     def load_data(data.json):
#                       ^
# SyntaxError: invalid syntax

# %%
print(data)
