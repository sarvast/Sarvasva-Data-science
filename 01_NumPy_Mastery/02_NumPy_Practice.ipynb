# %% [markdown]
# # 🏋️ NumPy Practice Arena
#
# Yahan tumhe apna dimaag lagana hai. Copy-paste mat karna. Koshish karo khud solve karne ki.
#
# Tip: Agar phas jao, toh Google use karo ya pichla notebook refer karo.

# %% [markdown]
# ### Challenge 1: The Creator
# 1. Ek array banao jisme **1 se 50** tak saare Even numbers ho (2, 4, 6...).
# 2. Us array ka `shape` print karo.

# %%
import numpy as np

# Code here

# %% [markdown]
# ### Challenge 2: The Matrix
# 1. Ek **5x5** ka matrix banao jo **Sirf 1s (Ones)** se bhara ho.
# 2. Phir usmein **sab jagah 5 add** kar do (Takki saare elements 6 ban jayein).

# %%
# Code here

# %% [markdown]
# ### Challenge 3: Filtering (Conditional Selection)
# Niche diye gaye array mein se woh number dhundo jo **20 se bade hain**.
#
# `arr = np.array([10, 15, 20, 25, 30, 5, 40])`

# %%
arr = np.array([10, 15, 20, 25, 30, 5, 40])

# Code here

# %% [markdown]
# ### Challenge 4: Reshape Master
# 1. `np.arange(1, 13)` use karke 1 se 12 tak number generate karo.
# 2. Is 1D array ko **4 rows aur 3 columns** (4x3) mein convert karo.

# %%
# Code here

# %% [markdown]
# ### Bonus Challenge 🌟
# Ek 10x10 ka random matrix banao aur uska:
# 1. **Maximum** value dhoondo.
# 2. **Minimum** value dhoondo.
# 3. **Mean** (Average) nikaalo.

# %%
# Code here
