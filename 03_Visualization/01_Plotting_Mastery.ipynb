# %% [markdown]
# # 📊 Visualization Mastery: Data ko Dekhna Seekho
#
# Numbers padhna boring hai. Graphs dekhna easy hai.
# Aaj hum 2 best libraries use karenge:
# 1. **Matplotlib**: Dada ji (Basic, Powerful).
# 2. **Seaborn**: Pota (Modern, Stylish, Statistical).
#
# ### Import Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Ye magic command graph ko notebook ke andar dikhati hai
# %matplotlib inline

print("Libraries Successfully Imported! 🚀")

# %% [markdown]
# ## 1. Line Plot (Basic Trend)
# Sabse simple graph. Time ke saath cheezein kaise badal rahi hain.

# %%
# Fake Data generate karte hain
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Matplotlib Plot
plt.figure(figsize=(10, 5))  # Size set karna
plt.plot(x, y, label='Sine Wave', color='blue', linestyle='--')
plt.title("Mera Pehla Graph (Sine Wave)")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.legend()  # Label dikhane ke liye
plt.grid(True) # Jaali lagana
plt.show()

# %% [markdown]
# ## 2. Scatter Plot (Relationships)
# Do cheezon ke beech rishta dekhne ke liye. (Jaise: Padhai vs Marks).

# %%
# Seaborn use karte hain (Zyada sundar hai)
hours_studied = [1, 2, 3, 4, 5, 6, 7, 8]
marks = [40, 50, 55, 60, 75, 80, 85, 95]

sns.scatterplot(x=hours_studied, y=marks, color='red', s=100)
plt.title("Padhai vs Marks")
plt.show()

# %% [markdown]
# ## 3. Bar Plot (Comparison)
# Alag-alag categories ko compare karna.

# %%
fruits = ['Apple', 'Banana', 'Mango', 'Orange']
prices = [100, 40, 60, 80]

sns.barplot(x=fruits, y=prices, palette='viridis')
plt.title("Fruit Prices")
plt.show()

# %% [markdown]
# ## 4. Histogram (Distribution)
# Data kaise phaila hua hai. (E.g. Class mein bacchon ki height).

# %%
data = np.random.randn(1000) # 1000 random numbers

sns.histplot(data, kde=True, color='purple')
plt.title("Normal Distribution (Ghanti jaisa shape)")
plt.show()

# %% [markdown]
# ## ⚖️ Practice Task
# 1. `numpy` se 2 arrays banao.
# 2. `matplotlib` se unka 'Scatter Plot' banao.
# 3. Title aur Labels zaroor dena.
